# %%
import sys
import os

# 현재 파일(main.ipynb)이 있는 디렉토리의 부모 디렉토리를 sys.path에 추가
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
# INFO 
from config import *

# MAIN
from network.resnet import *

from Omok.state import *
from Omok.trainer import *
from Omok.evalNetwork import *
from Omok.selfplay import *
from Omok.tester import *

# UTILS
from utils.saveLoad import *
from utils.valid_tool import *
from utils.setDevice import *
from utils.timer import *

# %%
State = select_state(STATE_DIM)
Selfplay = get_selfplay_class()

# %%
model = Network(N_RESIDUAL_BLOCK, N_KERNEL, STATE_DIM, N_ACTIONS)
params = torch.load(f"{F_CWD}/{P_NAME}/models/latest_model_weight.pth", weights_only=False, map_location=torch.device('cpu'))
model.load_state_dict(params)
# Out:
# <All keys matched successfully>

# %%
# vs_human = ModelvsHuman(eval_network.best_model)

vs_human = ModelvsHuman(model)
vs_human()
# Out:
# Alpha Zero's Action is : (4, 4)
# My action is (5, 5)
# Alpha Zero's Action is : (3, 5)
# My action is (5, 3)
# Alpha Zero's Action is : (0, 0)
# My action is (5, 4)
# Alpha Zero's Action is : (5, 2)
# My action is (5, 6)
# Alpha Zero's Action is : (5, 7)
# My action is (4, 3)
# Alpha Zero's Action is : (6, 3)
# My action is (3, 3)
# Alpha Zero's Action is : (4, 1)
# My action is (7, 4)
# Alpha Zero's Action is : (3, 0)
# My action is (3, 2)
# Alpha Zero's Action is : (6, 5)
# My action is (2, 1)
# Alpha Zero's Action is : (3, 1)
# My action is (1, 0)

# %%
def flatten_idx(coord):
    return coord[0] * STATE_SHAPE[1] + coord[1]
